# %% [markdown]
# ### PubMed Data Extraction and DataFrame Creation for Post-acute sequelae of SARS-CoV-2 Infection Publications
# This notebook is designed to retrieve information about scientific articles related to "post-COVID-19 syndrome" or "post-acute sequelae of SARS-CoV-2 infection". It achieves this by:
#
# 1. **Accessing PubMed:** It utilizes the PubMed database to search for relevant articles using specific keywords and filters (availability, language, publication type, etc.).
# 2. **Extracting Key Identifiers:** It retrieves PubMed IDs and PubMed Central IDs for the identified articles. (PMIDs, PMCIDs)
# 3. **Collecting Article Details:** For each article, it extracts the title and attempts to find a link to the full text PDF.
# 4. **Creating a Structured Dataset:** The extracted information (PMID, PMCID, title, PDF link, and article category) is organized into a pandas DataFrame.
# 4. **Data Cleaning:** Duplicate entries and entries with missing PMIDs are removed from the DataFrame.
#
# The resulting DataFrame provides a structured overview of the collected documents, serving as a valuable resource before further processing or transformation into a vector database.

# %% [markdown]
# #### Imports and Installation
# This section consist of imports of Python libraries, including requests, bs4, pandas, regex, time, shutil, and os, to facilitate web scraping, data processing, and file operations.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import regex as re
import math
import concurrent.futures
from urllib.parse import urljoin

# %%
import time
import shutil
import os

# %% [markdown]
# #### Source and Filter Initiation
# This section defines the base URL for querying the PubMed database and sets up various filters to refine the search results. The filters include:
#
# 1. **Availability:** Limiting results to free full-text articles.
# 2. **Language:** Restricting results to English publications.
# 3. **Display Settings:** Specifying the number of results per page.
# 4. **Format Display:** Setting the output format to include PubMed IDs (PMIDs).
# 5. **MEDLINE Filter:** Including articles indexed in MEDLINE.
# 6. **Sort Order:** Ordering results by publication date.
#
# These filters are concatenated with the base URL to create the final source URL used for retrieving article information. The constructed source URL is then printed.

# %%
url = """https://pubmed.ncbi.nlm.nih.gov/""" +\
      """?term="post-covid-19+syndrome"+""" +\
      """or+%28"post-acute+sequelae+of+SARS-CoV-2+infection"+and+"PACS"%29"""

# %%
availability_filter   = "&filter=simsearch2.ffrft"
language_filter       = "&filter=lang.english"
display_settings      = "&size=200"
format_display        = "&format=pmid"
medline_filter        = "&filter=other.medline"
sort_by_date          = "&sort=pubdate"

filter = availability_filter+language_filter+display_settings+format_display+medline_filter+sort_by_date

# %%
source = url+filter
print(source)
# Out:
# https://pubmed.ncbi.nlm.nih.gov/?term="post-covid-19+syndrome"+or+%28"post-acute+sequelae+of+SARS-CoV-2+infection"+and+"PACS"%29&filter=simsearch2.ffrft&filter=lang.english&size=200&format=pmid&filter=other.medline&sort=pubdate

# %% [markdown]
# #### pmids, pmcids, and articles title retrieval
#
# This section focuses on extracting the core information about the relevant articles from PubMed. It performs the following steps:
#
# 1.  **Retrieve PMIDs by category:** The `get_pmids` function is called for each defined article type (e.g., "case reports", "clinical study"). This function constructs specific PubMed query URLs and extracts lists of PubMed IDs (PMIDs) for each category, handling pagination to retrieve results across multiple pages.
# 2.  **Fetch PMCIDs and Titles:** The `get_pmcid_and_titles` function takes the lists of PMIDs and queries PubMed again for each individual PMID. It parses the returned information to extract the PubMed Central ID (PMCID) and the article title. The function includes error handling and a delay to manage requests effectively.
# 3.  **Structure the data:** The retrieved PMIDs, PMCIDs, and titles are stored in separate dictionaries for each article type, providing a structured representation of the initial data.
# 4.  **Assign Categories:** The `get_category` function adds a 'category' key to each dictionary, clearly labeling the article type for later use.

# %%
def get_pmids(article_type):
  list_of_pmids = []

  # limiting the process to 30 based on compute power limitation
  for i in range(30):
    pagination    = f"&page={i+1}"
    new_source    = source+article_type+pagination
    get_source    = requests.get(new_source)
    soup          = BeautifulSoup(get_source.content, 'html.parser')
    category      = re.search(r"pubt\.(.*)", article_type).group(1) if re.search(r"pubt\.(.*)", article_type) else None

    try:
      pmids = soup.find("pre").find(string=True).split("\r\n")
      list_of_pmids.extend(pmids)

      print(f"processing publications of {category}")
      print(f"retriving page-{i+1}")
    except AttributeError:
      print("done!\n")
      break
  return list_of_pmids

# %%
article_types = ["&filter=pubt.casereports",
                 "&filter=pubt.clinicalstudy",
                 "&filter=pubt.clinicaltrial",
                 "&filter=pubt.clinicaltrialphaseiii",
                 "&filter=pubt.clinicaltrialphaseiv",
                 "&filter=pubt.guideline",
                 "&filter=pubt.meta-analysis",
                 "&filter=pubt.patienteducationhandout",
                 "&filter=pubt.review",
                 "&filter=pubt.systematicreview"]

# %%
list_of_pmids_per_category = []

for i in article_types:
  cache = get_pmids(i)
  list_of_pmids_per_category.append(cache)
# Out:
# processing publications of casereports
# retriving page-1
# done!
#
# processing publications of clinicalstudy
# retriving page-1
# done!
#
# processing publications of clinicaltrial
# retriving page-1
# done!
#
# done!
#
# done!
#
# done!
#
# processing publications of meta-analysis
# retriving page-1
# done!
#
# done!
#
# processing publications of review
# retriving page-1
# done!
#
# processing publications of systematicreview
# retriving page-1
# done!

# %%
len(list_of_pmids_per_category)
# Out:
# 10

# %%
print(f"successfully retrieving: {len(list_of_pmids_per_category[0])} pmids of case-report")
print(f"successfully retrieving: {len(list_of_pmids_per_category[1])} pmids of clinical-study")
print(f"successfully retrieving: {len(list_of_pmids_per_category[2])} pmids of clinical-trial")
print(f"successfully retrieving: {len(list_of_pmids_per_category[3])} pmids of meta-analysis")
print(f"successfully retrieving: {len(list_of_pmids_per_category[4])} pmids of guideline")
print(f"successfully retrieving: {len(list_of_pmids_per_category[5])} pmids of clinical-trial-phase-four")
print(f"successfully retrieving: {len(list_of_pmids_per_category[6])} pmids of clinical-trial-phase-three")
print(f"successfully retrieving: {len(list_of_pmids_per_category[7])} pmids of patient-education-hands-out")
print(f"successfully retrieving: {len(list_of_pmids_per_category[8])} pmids of review")
print(f"successfully retrieving: {len(list_of_pmids_per_category[9])} pmids of systematic-review")
print(f"\ntotal documents availabe: {sum([len(per_category) for per_category in list_of_pmids_per_category])}")
# Out:
# successfully retrieving: 13 pmids of case-report
# successfully retrieving: 43 pmids of clinical-study
# successfully retrieving: 11 pmids of clinical-trial
# successfully retrieving: 0 pmids of meta-analysis
# successfully retrieving: 0 pmids of guideline
# successfully retrieving: 0 pmids of clinical-trial-phase-four
# successfully retrieving: 7 pmids of clinical-trial-phase-three
# successfully retrieving: 0 pmids of patient-education-hands-out
# successfully retrieving: 65 pmids of review
# successfully retrieving: 11 pmids of systematic-review
#
# total documents availabe: 150

# %%
def get_pmcid_and_titles(pmids, batch_size=10, delay=3):
    results = []
    session = requests.Session()
    total_batches = math.ceil(len(pmids) / batch_size)

    # Pre-compile regex patterns for efficiency
    pmc_pattern = re.compile(r"PMC - (PMC\d+)")
    title_pattern = re.compile(r"TI  - (.*?\.)(?=\n|\r|$)", re.DOTALL)

    for batch_idx in range(total_batches):
        start_idx = batch_idx * batch_size
        batch = pmids[start_idx:start_idx + batch_size]
        print(f"Processing batch {batch_idx + 1}/{total_batches}")

        for pmid in batch:
            url = f"https://pubmed.ncbi.nlm.nih.gov/{pmid}/?format=pubmed"
            result = {'pmid': pmid, 'pmcid': None, 'title': None}

            try:
                response = session.get(url, timeout=10)
                response.raise_for_status()
                soup = BeautifulSoup(response.content, 'html.parser')
                text = soup.get_text()

                # Single pass for both patterns
                if pmc_match := pmc_pattern.search(text):
                    result['pmcid'] = pmc_match.group(1).strip()

                if title_match := title_pattern.search(text):
                    result['title'] = ' '.join(title_match.group(1).split())

            except requests.exceptions.RequestException as e:
                print(f"Request failed for PMID {pmid}: {str(e)[:100]}")
            except Exception as e:
                print(f"Error processing PMID {pmid}: {str(e)[:100]}")
            finally:
                results.append(result)

        # Add delay between batches (except after last batch)
        if batch_idx < total_batches - 1:
            print(f"Waiting {delay} seconds before next batch...")
            time.sleep(delay)

    return results

# %%
case_report_dict = get_pmcid_and_titles(list_of_pmids_per_category[0])
# Out:
# Processing batch 1/2
# Waiting 3 seconds before next batch...
# Processing batch 2/2

# %%
case_report_dict
# Out:
# [{'pmid': '39621236',
#   'pmcid': 'PMC11971158',
#   'title': 'Syncopes, paresis and loss of vision after COVID-19 mRNA-based vaccination and SARS-CoV-2 infection.'},
#  {'pmid': '39988835',
#   'pmcid': 'PMC11868965',
#   'title': 'Severe COVID-19 Pneumonia, Opportunistic Candida krusei Infection, and Acute Respiratory Distress Syndrome with Pulmonary Arterial Hypertension Treated with Bosentan: A Case Report.'},
#  {'pmid': '39093769',
#   'pmcid': 'PMC11296404',
#   'title': 'Integrative personalized medicine care for adjustment disorder of a post-COVID-19 patient: A CARE-compliant case report.'},
#  {'pmid': '37606967',
#   'pmcid': 'PMC10469423',
#   'title': 'Severe pigeon paramyxovirus 1 infection in a human case with probable post-COVID-19 condition.'},
#  {'pmid': '36617353',
#   'pmcid': 'PMC9826535',
#   'title': 'Post-COVID-19 syndrome increased the requirement for corticosteroids in a dialysis patient with preexisting adrenal insufficiency.'},
#  {'pmid': '36581538',
#   'pmcid': 'PMC9767890',
#   'title': 'Post-intubation laryngeal injury after COVID-19 treatment causing dyspnea: A report of six cases.'},
#  {'pmid': '37052263',
#   'pmcid': 'PMC10102822',
#   'title': 'Successful Treatment of Post-COVID-19 ADHD-like Syndrome: A Case Report.'},
#  {'pmid': '36822507',
#   'pmcid': 'PMC9943558',
#   'title': 'Leveraging Serologic Testing to Identify Children at Risk For Post-Acute Sequelae of SARS-CoV-2 Infection: An Electronic Health Record-Based Cohort Study from the RECOVER Program.'},
#  {'pmid': '35839020',
#   'pmcid': 'PMC11132361',
#   'title': 'Local anesthetics as a therapeutic tool for post COVID-19 patients: A case report.'},
#  {'pmid': '35396239',
#   'pmcid': 'PMC8996041',
#   'title': 'Post-COVID-19 syndrome: persistent neuroimaging changes and symptoms 9 months after initial infection.'},
#  {'pmid': '35153293',
#   'pmcid': 'PMC8855328',
#   'title': 'Recurrent COVID-19 Polymerase Chain Reaction (PCR) Positivity in 2 Patients During the Current Health Care System Crisis.'},
#  {'pmid': '34727992',
#   'pmcid': 'PMC8561376',
#   'title': 'Post-coronavirus disease 2019 polyneuropathy with significant response to immunoglobulin therapy: a case report.'},
#  {'pmid': '33860871',
#   'pmcid': 'PMC8050227',
#   'title': 'Autonomic dysfunction following COVID-19 infection: an early experience.'}]

# %%
clinicalstudy_dict = get_pmcid_and_titles(list_of_pmids_per_category[1])
# Out:
# Processing batch 1/5
# Waiting 3 seconds before next batch...
# Processing batch 2/5
# Waiting 3 seconds before next batch...
# Processing batch 3/5
# Waiting 3 seconds before next batch...
# Processing batch 4/5
# Waiting 3 seconds before next batch...
# Processing batch 5/5

# %%
clinicalstudy_dict
# Out:
# [{'pmid': '40065313',
#   'pmcid': 'PMC11895281',
#   'title': 'The legacy of the COVID-19 pandemic for the healthcare environment: the establishment of long COVID/ Post-COVID-19 condition follow-up outpatient clinics in Germany.'},
#  {'pmid': '40003486',
#   'pmcid': 'PMC11855376',
#   'title': 'Comparative Analysis of Submaximal and Maximal Effort Capacities in Patients Post-COVID-19 and Individuals with Chronic Restrictive Lung Diseases.'},
#  {'pmid': '39905419',
#   'pmcid': 'PMC11792378',
#   'title': 'Balneotherapy for the treatment of post-COVID syndrome: a randomized controlled trial.'},
#  {'pmid': '39665835',
#   'pmcid': 'PMC11922198',
#   'title': 'Exercise rehabilitation in post COVID-19 patients: a randomized controlled trial of different training modalities.'},
#  {'pmid': '39423759',
#   'pmcid': None,
#   'title': 'Analysis of fat oxidation capacity during cardiopulmonary exercise testing indicates long-lasting metabolic disturbance in patients with post-covid-19 syndrome.'},
#  {'pmid': '39519343',
#   'pmcid': 'PMC11546864',
#   'title': 'Neutrophil Elastase, Neuron-Specific Enolase, and S100B Protein as Potential Markers of Long-Term Complications Caused by COVID-19 in Patients with Type 2 Diabetes Mellitus (T2DM) and Advanced Stage of Diabetic Nephropathy (NfT2DM)-Observational Studies.'},
#  {'pmid': '39472948',
#   'pmcid': 'PMC11520684',
#   'title': 'Digital rehabilitation care planning for people with chronic diseases (RehaPro-SERVE): study protocol for a German multicentre randomised controlled trial.'},
#  {'pmid': '38937986',
#   'pmcid': 'PMC11446691',
#   'title': 'Telerehabilitation improves cardiorespiratory and muscular fitness and body composition in older people with post-COVID-19 syndrome.'},
#  {'pmid': '38899867',
#   'pmcid': 'PMC11528924',
#   'title': 'Function and activity capacity at 1 year after the admission to intensive care unit for COVID-19.'},
#  {'pmid': '39285491',
#   'pmcid': 'PMC11404027',
#   'title': 'A prospective non-randomized controlled trial testing the effectiveness of psychotherapeutic inpatient treatment of Post-COVID-19 syndrome - study protocol.'},
#  {'pmid': '38436080',
#   'pmcid': None,
#   'title': 'Low-intensity rehabilitation in persistent post COVID-19 dyspnoea: the value of Spa health resort as appropriate setting.'},
#  {'pmid': '38739435',
#   'pmcid': 'PMC11130769',
#   'title': 'Evaluating the Feasibility, Acceptance, and Beneficial Effects of Online Occupational Therapy for Post-COVID-19 Condition: Protocol for a Randomized Controlled Trial (ErgoLoCo Study).'},
#  {'pmid': '38678234',
#   'pmcid': 'PMC11055275',
#   'title': 'Cancer-related fatigue and activities of daily living: lessons learned from the COVID-19 pandemic.'},
#  {'pmid': '37201931',
#   'pmcid': None,
#   'title': 'Vision impairment is common in non-hospitalised patients with post-COVID-19 syndrome.'},
#  {'pmid': '38528512',
#   'pmcid': 'PMC10964649',
#   'title': 'Effect of home-based pulmonary rehabilitation on exercise capacity in post COVID-19 patients: a randomized controlled trail.'},
#  {'pmid': '38424415',
#   'pmcid': 'PMC10904373',
#   'title': 'Characteristic functional connectome related to Post-COVID-19 syndrome.'},
#  {'pmid': '38184567',
#   'pmcid': 'PMC10771676',
#   'title': 'Feasibility, safety and effectiveness of prednisolone and vitamin B1, B6, and B12 in patients with post-COVID-19-syndrome (PreVitaCOV) - protocol of a randomised, double-blind, placebo-controlled multicentre trial in primary care (phase IIIb).'},
#  {'pmid': '38055548',
#   'pmcid': 'PMC10695477',
#   'title': 'Unsupervised natural language processing in the identification of patients with suspected COVID-19 infection.'},
#  {'pmid': '37507580',
#   'pmcid': 'PMC10542303',
#   'title': 'Persistent endothelial dysfunction in post-COVID-19 syndrome and its associations with symptom severity and chronic inflammation.'},
#  {'pmid': '38213055',
#   'pmcid': None,
#   'title': 'Effectiveness of Internet-Based Group Supportive Psychotherapy on Psychic and Somatic Symptoms, Neutrophil-Lymphocyte Ratio, and Heart Rate Variability in Post COVID-19 Syndrome Patients.'},
#  {'pmid': '37690207',
#   'pmcid': None,
#   'title': 'Factors associated with mental health outcomes after COVID-19: A 24-month follow-up longitudinal study.'},
#  {'pmid': '37681837',
#   'pmcid': 'PMC10488264',
#   'title': 'Post-COVID-19 Syndrome: Audiometric Findings in Patients with Audiological Symptoms.'},
#  {'pmid': '37184376',
#   'pmcid': None,
#   'title': 'Long-term consequences in Covid-19 and Non-Covid-19 patients survivors of critical illness. A descriptive study.'},
#  {'pmid': '37055254',
#   'pmcid': 'PMC9981521',
#   'title': 'Comparison of two antifibrotic treatments for lung fibrosis in post-COVID-19 syndrome: A randomized, prospective study.'},
#  {'pmid': '37301934',
#   'pmcid': 'PMC10257166',
#   'title': 'The effect of hyperbaric oxygen therapy on myocardial function in post-COVID-19 syndrome patients: a randomized controlled trial.'},
#  {'pmid': '37291679',
#   'pmcid': 'PMC10248954',
#   'title': 'Post-acute COVID-19 in three doses vaccinated autoimmune rheumatic diseases patients: frequency and pattern of this condition.'},
#  {'pmid': '37286327',
#   'pmcid': 'PMC10335413',
#   'title': 'Impact of fatigue as the primary determinant of functional limitations among patients with post-COVID-19 syndrome: a cross-sectional observational study.'},
#  {'pmid': '36996121',
#   'pmcid': 'PMC10062549',
#   'title': 'Chronic cough in post-COVID syndrome: Laryngeal electromyography findings in vagus nerve neuropathy.'},
#  {'pmid': '36476156',
#   'pmcid': 'PMC9829459',
#   'title': 'Effects of a concurrent training, respiratory muscle exercise, and self-management recommendations on recovery from post-COVID-19 conditions: the RECOVE trial.'},
#  {'pmid': '36410797',
#   'pmcid': 'PMC9680157',
#   'title': 'HEART rate variability biofeedback for long COVID symptoms (HEARTLOC): protocol for a feasibility study.'},
#  {'pmid': '36361102',
#   'pmcid': 'PMC9654654',
#   'title': 'Prevalence of Insomnia in the Early Post-COVID-19 Recovery Period.'},
#  {'pmid': '36121338',
#   'pmcid': 'PMC9608026',
#   'title': 'Influence of Manual Diaphragm Release Technique Combined with Inspiratory Muscle Training on Selected Persistent Symptoms in Men with Post-Covid-19 Syndrome: A Randomized Controlled Trial.'},
#  {'pmid': '36242061',
#   'pmcid': 'PMC9568911',
#   'title': 'Kangyi Qiangshen Gong exercise prescription for pulmonary function and quality of life in patients recovered from COVID-19: a study protocol for a randomized controlled trial.'},
#  {'pmid': '36042189',
#   'pmcid': 'PMC9426365',
#   'title': 'A prospective observational study of post-COVID-19 chronic fatigue syndrome following the first pandemic wave in Germany and biomarkers associated with symptom severity.'},
#  {'pmid': '35994441',
#   'pmcid': 'PMC9394845',
#   'title': 'Comparison between the persistence of post COVID-19 symptoms on critical patients requiring invasive mechanical ventilation and non-critical patients.'},
#  {'pmid': '35301101',
#   'pmcid': 'PMC8920113',
#   'title': 'Assessing the impact of COVID-19 at 1-year using the SF-12 questionnaire: Data from the Anticipate longitudinal cohort study.'},
#  {'pmid': '34676578',
#   'pmcid': 'PMC8662016',
#   'title': 'The COVID-19 Yorkshire Rehabilitation Scale (C19-YRS): Application and psychometric analysis in a post-COVID-19 syndrome cohort.'},
#  {'pmid': '35131031',
#   'pmcid': 'PMC8896831',
#   'title': 'Investigating phenotypes of pulmonary COVID-19 recovery: A longitudinal observational prospective multicenter trial.'},
#  {'pmid': '34857010',
#   'pmcid': 'PMC8637041',
#   'title': 'A randomised controlled trial testing the efficacy of Fit after COVID, a cognitive behavioural therapy targeting severe post-infectious fatigue following COVID-19 (ReCOVer): study protocol.'},
#  {'pmid': '34719599',
#   'pmcid': None,
#   'title': 'Post COVID-19 sequelae: A prospective observational study from Northern India.'},
#  {'pmid': '34494964',
#   'pmcid': 'PMC8457337',
#   'title': 'Severe Fatigue in Long COVID: Web-Based Quantitative Follow-up Study in Members of Online Long COVID Support Groups.'},
#  {'pmid': '33831043',
#   'pmcid': 'PMC8031743',
#   'title': 'Post-COVID-19 syndrome among symptomatic COVID-19 patients: A prospective cohort study in a tertiary care center of Bangladesh.'},
#  {'pmid': '33785495',
#   'pmcid': 'PMC8727683',
#   'title': 'Multiorgan impairment in low-risk individuals with post-COVID-19 syndrome: a prospective, community-based study.'}]

# %%
clinicaltrial_dict = get_pmcid_and_titles(list_of_pmids_per_category[2])
# Out:
# Processing batch 1/2
# Waiting 3 seconds before next batch...
# Processing batch 2/2

# %%
clinicaltrial_dict
# Out:
# [{'pmid': '39905419',
#   'pmcid': 'PMC11792378',
#   'title': 'Balneotherapy for the treatment of post-COVID syndrome: a randomized controlled trial.'},
#  {'pmid': '39665835',
#   'pmcid': 'PMC11922198',
#   'title': 'Exercise rehabilitation in post COVID-19 patients: a randomized controlled trial of different training modalities.'},
#  {'pmid': '38937986',
#   'pmcid': 'PMC11446691',
#   'title': 'Telerehabilitation improves cardiorespiratory and muscular fitness and body composition in older people with post-COVID-19 syndrome.'},
#  {'pmid': '38528512',
#   'pmcid': 'PMC10964649',
#   'title': 'Effect of home-based pulmonary rehabilitation on exercise capacity in post COVID-19 patients: a randomized controlled trail.'},
#  {'pmid': '38213055',
#   'pmcid': None,
#   'title': 'Effectiveness of Internet-Based Group Supportive Psychotherapy on Psychic and Somatic Symptoms, Neutrophil-Lymphocyte Ratio, and Heart Rate Variability in Post COVID-19 Syndrome Patients.'},
#  {'pmid': '37055254',
#   'pmcid': 'PMC9981521',
#   'title': 'Comparison of two antifibrotic treatments for lung fibrosis in post-COVID-19 syndrome: A randomized, prospective study.'},
#  {'pmid': '37301934',
#   'pmcid': 'PMC10257166',
#   'title': 'The effect of hyperbaric oxygen therapy on myocardial function in post-COVID-19 syndrome patients: a randomized controlled trial.'},
#  {'pmid': '36476156',
#   'pmcid': 'PMC9829459',
#   'title': 'Effects of a concurrent training, respiratory muscle exercise, and self-management recommendations on recovery from post-COVID-19 conditions: the RECOVE trial.'},
#  {'pmid': '36121338',
#   'pmcid': 'PMC9608026',
#   'title': 'Influence of Manual Diaphragm Release Technique Combined with Inspiratory Muscle Training on Selected Persistent Symptoms in Men with Post-Covid-19 Syndrome: A Randomized Controlled Trial.'},
#  {'pmid': '35131031',
#   'pmcid': 'PMC8896831',
#   'title': 'Investigating phenotypes of pulmonary COVID-19 recovery: A longitudinal observational prospective multicenter trial.'},
#  {'pmid': '33831043',
#   'pmcid': 'PMC8031743',
#   'title': 'Post-COVID-19 syndrome among symptomatic COVID-19 patients: A prospective cohort study in a tertiary care center of Bangladesh.'}]

# %%
meta_analysis_dict = get_pmcid_and_titles(list_of_pmids_per_category[3])

# %%
meta_analysis_dict #there are no data for meta analysis
# Out:
# []

# %%
guideline_dict = get_pmcid_and_titles(list_of_pmids_per_category[4])

# %%
guideline_dict #there are no data for patient guidelines
# Out:
# []

# %%
clinicalfour_dict = get_pmcid_and_titles(list_of_pmids_per_category[5])

# %%
clinicalfour_dict #there are no data for clinical phase four
# Out:
# []

# %%
clinicalthree_dict = get_pmcid_and_titles(list_of_pmids_per_category[6])
# Out:
# Processing batch 1/1

# %%
clinicalthree_dict
# Out:
# [{'pmid': '40305533',
#   'pmcid': None,
#   'title': 'Predictors of post-COVID-19 syndrome: a meta-analysis.'},
#  {'pmid': '38834107',
#   'pmcid': None,
#   'title': 'Early use of oral antiviral drugs and the risk of post COVID-19 syndrome: A systematic review and network meta-analysis.'},
#  {'pmid': '38321404',
#   'pmcid': 'PMC10848453',
#   'title': 'The global prevalence of depression, anxiety, and sleep disorder among patients coping with Post COVID-19 syndrome (long COVID): a systematic review and meta-analysis.'},
#  {'pmid': '36990297',
#   'pmcid': 'PMC10067136',
#   'title': 'COVID-19 vaccination for the prevention and treatment of long COVID: A systematic review and meta-analysis.'},
#  {'pmid': '35339066',
#   'pmcid': 'PMC8934180',
#   'title': 'Call for correction: Mid and long-term neurological and neuropsychiatric manifestations of post-COVID-19 syndrome: A meta-analysis.'},
#  {'pmid': '35121209',
#   'pmcid': 'PMC8798975',
#   'title': 'Mid and long-term neurological and neuropsychiatric manifestations of post-COVID-19 syndrome: A meta-analysis.'},
#  {'pmid': '34973396',
#   'pmcid': 'PMC8715665',
#   'title': 'Fatigue and cognitive impairment in Post-COVID-19 Syndrome: A systematic review and meta-analysis.'}]

# %%
patienthandsout_dict = get_pmcid_and_titles(list_of_pmids_per_category[7])

# %%
patienthandsout_dict
# Out:
# []

# %%
review_dict = get_pmcid_and_titles(list_of_pmids_per_category[8])
# Out:
# Processing batch 1/7
# Request failed for PMID 37834270: 429 Client Error: Too Many Requests for url: https://pubmed.ncbi.nlm.nih.gov/error/429.shtml
# Waiting 3 seconds before next batch...
# Processing batch 2/7
# Waiting 3 seconds before next batch...
# Processing batch 3/7
# Waiting 3 seconds before next batch...
# Processing batch 4/7
# Waiting 3 seconds before next batch...
# Processing batch 5/7
# Waiting 3 seconds before next batch...
# Processing batch 6/7
# Waiting 3 seconds before next batch...
# Processing batch 7/7

# %%
review_dict #found three title that need to be neated PMID: {37106076, 36066294, 34140635}
# Out:
# [{'pmid': '40305533',
#   'pmcid': None,
#   'title': 'Predictors of post-COVID-19 syndrome: a meta-analysis.'},
#  {'pmid': '39362575',
#   'pmcid': None,
#   'title': 'Immune Response and Cognitive Impairment in Post-COVID Syndrome: A Systematic Review.'},
#  {'pmid': '39934846',
#   'pmcid': 'PMC11818037',
#   'title': 'Assessment of psychosocial aspects in adults in post-COVID-19 condition: the EURONET-SOMA recommendations on core outcome domains for clinical and research use.'},
#  {'pmid': '39183058',
#   'pmcid': 'PMC11436955',
#   'title': 'Long COVID among healthcare workers: a narrative review of definitions, prevalence, symptoms, risk factors and impacts.'},
#  {'pmid': '38834107',
#   'pmcid': None,
#   'title': 'Early use of oral antiviral drugs and the risk of post COVID-19 syndrome: A systematic review and network meta-analysis.'},
#  {'pmid': '38392036',
#   'pmcid': 'PMC10886368',
#   'title': 'The Growing Understanding of the Pituitary Implication in the Pathogenesis of Long COVID-19 Syndrome: A Narrative Review.'},
#  {'pmid': '38321404',
#   'pmcid': 'PMC10848453',
#   'title': 'The global prevalence of depression, anxiety, and sleep disorder among patients coping with Post COVID-19 syndrome (long COVID): a systematic review and meta-analysis.'},
#  {'pmid': '38139400',
#   'pmcid': 'PMC10743535',
#   'title': 'Resveratrol and Gut Microbiota Synergy: Preventive and Therapeutic Effects.'},
#  {'pmid': '38004010',
#   'pmcid': 'PMC10673195',
#   'title': 'Post-COVID-19 and Irritable Bowel Syndrome: A Literature Review.'},
#  {'pmid': '37834270', 'pmcid': None, 'title': None},
#  {'pmid': '37595427',
#   'pmcid': None,
#   'title': 'Post-COVID-19 syndrome management: Utilizing the potential of dietary polysaccharides.'},
#  {'pmid': '37423295',
#   'pmcid': None,
#   'title': 'Chronic inflammation, neuroglial dysfunction, and plasmalogen deficiency as a new pathobiological hypothesis addressing the overlap between post-COVID-19 symptoms and myalgic encephalomyelitis/chronic fatigue syndrome.'},
#  {'pmid': '37021969',
#   'pmcid': None,
#   'title': 'Psychiatric manifestations of post-COVID-19 syndrome: the potential benefit of Silexan.'},
#  {'pmid': '36990297',
#   'pmcid': 'PMC10067136',
#   'title': 'COVID-19 vaccination for the prevention and treatment of long COVID: A systematic review and meta-analysis.'},
#  {'pmid': '37359549',
#   'pmcid': 'PMC10287165',
#   'title': 'The multifaceted nature of IL-10: regulation, role in immunological homeostasis and its relevance to cancer, COVID-19 and post-COVID conditions.'},
#  {'pmid': '37106076',
#   'pmcid': 'PMC10136381',
#   'title': 'Post-COVID-More than chronic fatigue? PG - 229-233 LID - 10.1007/s00059-023-05170-w [doi] AB - After the first COVID-19 survivors were medically treated in Germany from spring 2020 onwards, various courses of the disease emerged that, in addition to the acute infection, led to prolonged symptoms (long COVID), but also to a symptomatic course beyond 12 weeks, which is referred to as "post-COVID syndrome" (PCS). Currently, the incidence of PCS is estimated to be approximately 15% of all symptomatically infected patients, although over- or underestimations may occur due to the soft definition and lack of control groups. The etiology of PCS is currently unknown. The following pathogenetic processes are discussed in particular: an endothelial dysfunction with microcirculatory disturbances and subsequent organ damage, a residual virus or virus particles, and/or an excessive autoimmune process. Due to the large number of organs that may be affected, PCS presents as a very complex clinical picture with up to 200 described symptoms. An evidence-based causal therapy for PCS has not yet been established. The guideline-based inpatient rehabilitation measures adapted to the individual patient resources have proven to be an effective therapy and should therefore be involved in the therapeutic concept at an early stage. Post-COVID syndrome is a multicomplex disease that can have a considerable impact on the quality of life, but also on the professional performance of the affected patients. Thus, it is clearly more than just a chronic fatigue syndrome. In the interest of our patients, treating physicians should take this disease seriously, clarify the differential diagnoses, and provide sensitive therapeutic care.'},
#  {'pmid': '36174796',
#   'pmcid': 'PMC9512521',
#   'title': 'Post-COVID cholangiopathy: A narrative review.'},
#  {'pmid': '37241050',
#   'pmcid': 'PMC10221134',
#   'title': 'COVID-19 and Sleep Disturbances: A Literature Review of Clinical Evidence.'},
#  {'pmid': '37070922', 'pmcid': None, 'title': 'COVID-19 and bone health.'},
#  {'pmid': '37047556',
#   'pmcid': 'PMC10094973',
#   'title': 'COVID-19 and Diarylamidines: The Parasitic Connection.'},
#  {'pmid': '36708608',
#   'pmcid': 'PMC9840228',
#   'title': 'Towards evidence-based and inclusive models of peer support for long covid: A hermeneutic systematic review.'},
#  {'pmid': '36851746',
#   'pmcid': 'PMC9964207',
#   'title': 'Post-COVID-19 Syndrome Comprehensive Assessment: From Clinical Diagnosis to Imaging and Biochemical-Guided Diagnosis and Management.'},
#  {'pmid': '36937488',
#   'pmcid': 'PMC10015558',
#   'title': 'Post-COVID-19 syndrome: Insights into a novel post-infectious systemic disorder.'},
#  {'pmid': '35839441',
#   'pmcid': 'PMC9828583',
#   'title': 'Cardiac Complications of COVID-19 Infection and the Role of Physical Activity.'},
#  {'pmid': '36534494',
#   'pmcid': None,
#   'title': 'Assessment of life quality and health perception among recovered COVID-19 patients: multivariate analysis - own material and a review of previous reports on life quality assessment among convalescents.'},
#  {'pmid': '36560801',
#   'pmcid': 'PMC9784943',
#   'title': 'Efficacy of Therapeutic Exercise in Reversing Decreased Strength, Impaired Respiratory Function, Decreased Physical Fitness, and Decreased Quality of Life Caused by the Post-COVID-19 Syndrome.'},
#  {'pmid': '36379152',
#   'pmcid': 'PMC9637536',
#   'title': 'Role of SARS-CoV-2-induced cytokine storm in multi-organ failure: Molecular pathways and potential therapeutic options.'},
#  {'pmid': '36560604',
#   'pmcid': 'PMC9781151',
#   'title': 'A Comprehensive Report of German Nationwide Inpatient Data on the Post-COVID-19 Syndrome Including Annual Direct Healthcare Costs.'},
#  {'pmid': '35428040',
#   'pmcid': None,
#   'title': 'An overview of post COVID sequelae.'},
#  {'pmid': '35138001',
#   'pmcid': 'PMC9111040',
#   'title': 'Neurological complications associated with Covid-19; molecular mechanisms and therapeutic approaches.'},
#  {'pmid': '35489015',
#   'pmcid': 'PMC9055372',
#   'title': 'Evidence mapping and review of long-COVID and its underlying pathophysiological mechanism.'},
#  {'pmid': '35780756',
#   'pmcid': 'PMC9187867',
#   'title': 'Cognitive impairment in people with previous COVID-19 infection: A scoping review.'},
#  {'pmid': '36066294',
#   'pmcid': None,
#   'title': "Multisystem involvement in COVID-19: what have we learnt? PG - 1-5 LID - 10.12968/hmed.2022.0290 [doi] AB - The COVID-19 illness trajectory involves persistent cardio-renal inflammation, activation of the haemostatic pathway and lung involvement. Results of a study carried out by the authors' team demonstrate a link between post-COVID-19 syndrome (people who have long COVID) and multisystem disease, which partly explains the lingering impairments in patient-reported health-related quality of life, physical function and psychological wellbeing after COVID-19. This article discusses what hospital physicians need to be aware of when considering the likelihood of myocarditis in patients with post-COVID-19 syndrome and the implications in the longer term."},
#  {'pmid': '36016309',
#   'pmcid': 'PMC9413998',
#   'title': 'Pathogenic Connections in Post-COVID Conditions: What Do We Know in the Large Unknown? A Narrative Review.'},
#  {'pmid': '35177424',
#   'pmcid': 'PMC9258567',
#   'title': 'Molecular Imaging Findings on Acute and Long-Term Effects of COVID-19 on the Brain: A Systematic Review.'},
#  {'pmid': '35632823',
#   'pmcid': 'PMC9147674',
#   'title': 'Dysregulated Immune Responses in SARS-CoV-2-Infected Patients: A Comprehensive Overview.'},
#  {'pmid': '35302260',
#   'pmcid': 'PMC9111001',
#   'title': 'Therapeutic and prophylactic effect of flavonoids in post-COVID-19 therapy.'},
#  {'pmid': '35182777',
#   'pmcid': 'PMC8848724',
#   'title': 'The autonomic aspects of the post-COVID19 syndrome.'},
#  {'pmid': '35457093',
#   'pmcid': 'PMC9028501',
#   'title': 'Dissecting the Molecular Mechanisms Surrounding Post-COVID-19 Syndrome and Neurological Features.'},
#  {'pmid': '35334962',
#   'pmcid': 'PMC8954128',
#   'title': 'Dietary Recommendations for Post-COVID-19 Syndrome.'},
#  {'pmid': '35121209',
#   'pmcid': 'PMC8798975',
#   'title': 'Mid and long-term neurological and neuropsychiatric manifestations of post-COVID-19 syndrome: A meta-analysis.'},
#  {'pmid': '35309344',
#   'pmcid': 'PMC8924116',
#   'title': 'NETosis and Neutrophil Extracellular Traps in COVID-19: Immunothrombosis and Beyond.'},
#  {'pmid': '35363367',
#   'pmcid': None,
#   'title': 'The endocrine system function disturbances during and after SARS-CoV-2 infection.'},
#  {'pmid': '34973396',
#   'pmcid': 'PMC8715665',
#   'title': 'Fatigue and cognitive impairment in Post-COVID-19 Syndrome: A systematic review and meta-analysis.'},
#  {'pmid': '34655247',
#   'pmcid': 'PMC8661973',
#   'title': 'Covid-19 sequelae in working age patients: A systematic review.'},
#  {'pmid': '35163638',
#   'pmcid': 'PMC8835786',
#   'title': 'SARS-CoV-2-Specific Immune Response and the Pathogenesis of COVID-19.'},
#  {'pmid': '35105985',
#   'pmcid': 'PMC9127978',
#   'title': 'Pathological sequelae of long-haul COVID.'},
#  {'pmid': '34845562',
#   'pmcid': 'PMC8629735',
#   'title': 'Long COVID from rheumatology perspective - a narrative review.'},
#  {'pmid': '36657113',
#   'pmcid': None,
#   'title': 'What is post-COVID-19 syndrome? Definition and update.'},
#  {'pmid': '34140635',
#   'pmcid': 'PMC8209771',
#   'title': 'Chronic post-COVID-19 syndrome and chronic fatigue syndrome: Is there a role for extracorporeal apheresis? PG - 34-37 LID - 10.1038/s41380-021-01148-4 [doi] AB - As millions of patients have been infected by SARS-CoV-2 virus a vast number of individuals complain about continuing breathlessness and fatigue even months after the onset of the disease. This overwhelming phenomenon has not been well defined and has been called "post-COVID syndrome" or "long-COVID" [1]. There are striking similarities to myalgic encephalomyelitis also called chronic fatigue syndrome linked to a viral and autoimmune pathogenesis. In both disorders neurotransmitter receptor antibodies against ß-adrenergic and muscarinic receptors may play a key role. We found similar elevation of these autoantibodies in both patient groups. Extracorporeal apheresis using a special filter seems to be effective in reducing these antibodies in a significant way clearly improving the debilitating symptoms of patients with chronic fatigue syndrome. Therefore, such a form of neuropheresis may provide a promising therapeutic option for patients with post-COVID-19 syndrome. This method will also be effective when other hitherto unknown antibodies and inflammatory mediators are involved.'},
#  {'pmid': '34619491',
#   'pmcid': 'PMC8482840',
#   'title': 'Onset and frequency of depression in post-COVID-19 syndrome: A systematic review.'},
#  {'pmid': '34319569',
#   'pmcid': 'PMC8317481',
#   'title': 'Long COVID, a comprehensive systematic scoping review.'},
#  {'pmid': '34809664',
#   'pmcid': 'PMC8607226',
#   'title': 'An attempt to explain the neurological symptoms of Myalgic Encephalomyelitis/Chronic Fatigue Syndrome.'},
#  {'pmid': '34940980',
#   'pmcid': 'PMC8646640',
#   'title': 'Intravenous immunoglobulin as an important adjunct in the prevention and therapy of coronavirus 2019 disease.'},
#  {'pmid': '34160029',
#   'pmcid': 'PMC8420624',
#   'title': 'Apparent Discordance Between the Epidemiology of COVID-19 and Recommended Outcomes and Treatments: A Scoping Review.'},
#  {'pmid': '34024217',
#   'pmcid': 'PMC8146298',
#   'title': 'Long COVID or post-COVID-19 syndrome: putative pathophysiology, risk factors, and treatments.'},
#  {'pmid': '34384972',
#   'pmcid': 'PMC8317446',
#   'title': 'Post COVID-19 Syndrome ("Long COVID") and Diabetes: Challenges in Diagnosis and Management.'},
#  {'pmid': '34265229',
#   'pmcid': 'PMC8450986',
#   'title': 'Symptoms, complications and management of long COVID: a review.'},
#  {'pmid': '34175230',
#   'pmcid': 'PMC8180841',
#   'title': 'Insights from myalgic encephalomyelitis/chronic fatigue syndrome may help unravel the pathogenesis of postacute COVID-19 syndrome.'},
#  {'pmid': '34486708',
#   'pmcid': None,
#   'title': 'Staying tuned for post-COVID-19 syndrome: looking for new research to sniff out.'},
#  {'pmid': '34042167',
#   'pmcid': None,
#   'title': 'Post-COVID-19 syndrome: epidemiology, diagnostic criteria and pathogenic mechanisms involved.'},
#  {'pmid': '34067776',
#   'pmcid': 'PMC8156194',
#   'title': 'Post-COVID-19 Syndrome and the Potential Benefits of Exercise.'},
#  {'pmid': '34066174',
#   'pmcid': 'PMC8151698',
#   'title': 'A Review of Prolonged Post-COVID-19 Symptoms and Their Implications on Dental Management.'},
#  {'pmid': '33941272',
#   'pmcid': 'PMC8090526',
#   'title': "COVID-19 and Alzheimer's disease: how one crisis worsens the other."},
#  {'pmid': '33633106',
#   'pmcid': 'PMC7924007',
#   'title': 'Historical Insight into Infections and Disorders Associated with Neurological and Psychiatric Sequelae Similar to Long COVID.'}]

# %%
system_review_dict = get_pmcid_and_titles(list_of_pmids_per_category[9])
# Out:
# Processing batch 1/2
# Waiting 3 seconds before next batch...
# Processing batch 2/2

# %%
system_review_dict
# Out:
# [{'pmid': '40305533',
#   'pmcid': None,
#   'title': 'Predictors of post-COVID-19 syndrome: a meta-analysis.'},
#  {'pmid': '39362575',
#   'pmcid': None,
#   'title': 'Immune Response and Cognitive Impairment in Post-COVID Syndrome: A Systematic Review.'},
#  {'pmid': '38834107',
#   'pmcid': None,
#   'title': 'Early use of oral antiviral drugs and the risk of post COVID-19 syndrome: A systematic review and network meta-analysis.'},
#  {'pmid': '38321404',
#   'pmcid': 'PMC10848453',
#   'title': 'The global prevalence of depression, anxiety, and sleep disorder among patients coping with Post COVID-19 syndrome (long COVID): a systematic review and meta-analysis.'},
#  {'pmid': '36990297',
#   'pmcid': 'PMC10067136',
#   'title': 'COVID-19 vaccination for the prevention and treatment of long COVID: A systematic review and meta-analysis.'},
#  {'pmid': '36708608',
#   'pmcid': 'PMC9840228',
#   'title': 'Towards evidence-based and inclusive models of peer support for long covid: A hermeneutic systematic review.'},
#  {'pmid': '35177424',
#   'pmcid': 'PMC9258567',
#   'title': 'Molecular Imaging Findings on Acute and Long-Term Effects of COVID-19 on the Brain: A Systematic Review.'},
#  {'pmid': '34973396',
#   'pmcid': 'PMC8715665',
#   'title': 'Fatigue and cognitive impairment in Post-COVID-19 Syndrome: A systematic review and meta-analysis.'},
#  {'pmid': '34655247',
#   'pmcid': 'PMC8661973',
#   'title': 'Covid-19 sequelae in working age patients: A systematic review.'},
#  {'pmid': '34619491',
#   'pmcid': 'PMC8482840',
#   'title': 'Onset and frequency of depression in post-COVID-19 syndrome: A systematic review.'},
#  {'pmid': '34066174',
#   'pmcid': 'PMC8151698',
#   'title': 'A Review of Prolonged Post-COVID-19 Symptoms and Their Implications on Dental Management.'}]

# %%
def get_category(cat_dict, category_name):
  for item in cat_dict:
    item.update({"category": category_name})

# %%
get_category(clinicalthree_dict, "clinical trial phase three")
get_category(clinicalfour_dict, "clinical trial phase four")
get_category(case_report_dict, "case report")
get_category(guideline_dict, "guideline")
get_category(patienthandsout_dict, "patient education hands out")
get_category(clinicalstudy_dict, "clinical study")
get_category(clinicaltrial_dict, "clinical trial")
get_category(review_dict, "review")
get_category(system_review_dict, "systematic review")

# %%
database = pd.DataFrame(case_report_dict+guideline_dict+clinicalfour_dict+clinicalthree_dict+patienthandsout_dict+clinicalstudy_dict+clinicaltrial_dict+review_dict+system_review_dict)
database.sample(10)
# Out:
#          pmid        pmcid                                              title  \
# 115  35309344   PMC8924116  NETosis and Neutrophil Extracellular Traps in ...
# 2    39093769  PMC11296404  Integrative personalized medicine care for adj...
# 37   38055548  PMC10695477  Unsupervised natural language processing in th...
# 70   36476156   PMC9829459  Effects of a concurrent training, respiratory ...
# 141  38834107         None  Early use of oral antiviral drugs and the risk...
# 93   37047556  PMC10094973  COVID-19 and Diarylamidines: The Parasitic Con...
# 18   35121209   PMC8798975  Mid and long-term neurological and neuropsychi...
# 30   38436080         None  Low-intensity rehabilitation in persistent pos...
# 98   36534494         None  Assessment of life quality and health percepti...
# 114  35121209   PMC8798975  Mid and long-term neurological and neuropsychi...
#
#                        category
# 115                      review
# 2                   case report
# 37               clinical study
# 70               clinical trial
# 141           systematic review
# 93                       review
# 18   clinical trial phase three
# 30               clinical study
# 98                       review
# 114                      review

# %%
database.isna().sum()
# Out:
# pmid         0
# pmcid       28
# title        1
# category     0
# dtype: int64

# %% [markdown]
# #### Creating PMC Source Links
#
# This section generates the full links to the articles hosted on PubMed Central (PMC) using the extracted PMC IDs.
#
# 1.  **Iterating and Generating Links:** The code iterates through the list of PMC IDs obtained in the previous step. For each valid PMC ID, it constructs the complete URL to the article on the PMC website.
# 2.  **Handling Missing Links:** If an article does not have a corresponding PMC ID, the link for that article is set to `None`, and a message is printed to indicate the missing link.
# 3.  **Storing the Links:** The generated PMC links (or `None` for missing entries) are collected in a list.
# 4.  **Adding Links to DataFrame:** This list of PMC links is then added as a new column (`pmc_link`) to the `database` DataFrame, associating each article with its potential PMC source URL.

# %%
pmcid_links = []
for i,j in enumerate(database.pmcid):
  if j!=None:
    links = "https://pmc.ncbi.nlm.nih.gov/articles/{}/".format(j)
  else:
    links = None
    print(f"No PMC links found for index-{i}")
  pmcid_links.append(links)
# Out:
# No PMC links found for index-13
# No PMC links found for index-14
# No PMC links found for index-24
# No PMC links found for index-30
# No PMC links found for index-33
# No PMC links found for index-39
# No PMC links found for index-40
# No PMC links found for index-42
# No PMC links found for index-59
# No PMC links found for index-67
# No PMC links found for index-74
# No PMC links found for index-75
# No PMC links found for index-78
# No PMC links found for index-83
# No PMC links found for index-84
# No PMC links found for index-85
# No PMC links found for index-86
# No PMC links found for index-92
# No PMC links found for index-98
# No PMC links found for index-102
# No PMC links found for index-106
# No PMC links found for index-116
# No PMC links found for index-122
# No PMC links found for index-133
# No PMC links found for index-134
# No PMC links found for index-139
# No PMC links found for index-140
# No PMC links found for index-141

# %%
pmcid_links
# Out:
# ['https://pmc.ncbi.nlm.nih.gov/articles/PMC11971158/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC11868965/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC11296404/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10469423/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9826535/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9767890/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10102822/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9943558/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC11132361/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8996041/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8855328/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8561376/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8050227/',
#  None,
#  None,
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10848453/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10067136/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8934180/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8798975/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8715665/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC11895281/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC11855376/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC11792378/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC11922198/',
#  None,
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC11546864/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC11520684/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC11446691/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC11528924/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC11404027/',
#  None,
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC11130769/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC11055275/',
#  None,
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10964649/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10904373/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10771676/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10695477/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10542303/',
#  None,
#  None,
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10488264/',
#  None,
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9981521/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10257166/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10248954/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10335413/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10062549/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9829459/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9680157/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9654654/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9608026/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9568911/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9426365/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9394845/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8920113/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8662016/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8896831/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8637041/',
#  None,
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8457337/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8031743/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8727683/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC11792378/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC11922198/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC11446691/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10964649/',
#  None,
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9981521/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10257166/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9829459/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9608026/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8896831/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8031743/',
#  None,
#  None,
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC11818037/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC11436955/',
#  None,
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10886368/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10848453/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10743535/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10673195/',
#  None,
#  None,
#  None,
#  None,
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10067136/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10287165/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10136381/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9512521/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10221134/',
#  None,
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10094973/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9840228/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9964207/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10015558/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9828583/',
#  None,
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9784943/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9637536/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9781151/',
#  None,
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9111040/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9055372/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9187867/',
#  None,
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9413998/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9258567/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9147674/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9111001/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8848724/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9028501/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8954128/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8798975/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8924116/',
#  None,
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8715665/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8661973/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8835786/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9127978/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8629735/',
#  None,
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8209771/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8482840/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8317481/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8607226/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8646640/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8420624/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8146298/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8317446/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8450986/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8180841/',
#  None,
#  None,
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8156194/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8151698/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8090526/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC7924007/',
#  None,
#  None,
#  None,
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10848453/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC10067136/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9840228/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC9258567/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8715665/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8661973/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8482840/',
#  'https://pmc.ncbi.nlm.nih.gov/articles/PMC8151698/']

# %%
database = pd.concat([database, pd.DataFrame({"pmc_link":pmcid_links})], axis=1)

# %%
database.sample(10)
# Out:
#          pmid        pmcid                                              title  \
# 117  34973396   PMC8715665  Fatigue and cognitive impairment in Post-COVID...
# 144  36708608   PMC9840228  Towards evidence-based and inclusive models of...
# 102  35428040         None                An overview of post COVID sequelae.
# 75   39362575         None  Immune Response and Cognitive Impairment in Po...
# 148  34619491   PMC8482840  Onset and frequency of depression in post-COVI...
# 79   38392036  PMC10886368  The Growing Understanding of the Pituitary Imp...
# 145  35177424   PMC9258567  Molecular Imaging Findings on Acute and Long-T...
# 4    36617353   PMC9826535  Post-COVID-19 syndrome increased the requireme...
# 19   34973396   PMC8715665  Fatigue and cognitive impairment in Post-COVID...
# 37   38055548  PMC10695477  Unsupervised natural language processing in th...
#
#                        category  \
# 117                      review
# 144           systematic review
# 102                      review
# 75                       review
# 148           systematic review
# 79                       review
# 145           systematic review
# 4                   case report
# 19   clinical trial phase three
# 37               clinical study
#
#                                               pmc_link
# 117  https://pmc.ncbi.nlm.nih.gov/articles/PMC8715665/
# 144  https://pmc.ncbi.nlm.nih.gov/articles/PMC9840228/
# 102                                               None
# 75                                                None
# 148  https://pmc.ncbi.nlm.nih.gov/articles/PMC8482840/
# 79   https://pmc.ncbi.nlm.nih.gov/articles/PMC10886...
# 145  https://pmc.ncbi.nlm.nih.gov/articles/PMC9258567/
# 4    https://pmc.ncbi.nlm.nih.gov/articles/PMC9826535/
# 19   https://pmc.ncbi.nlm.nih.gov/articles/PMC8715665/
# 37   https://pmc.ncbi.nlm.nih.gov/articles/PMC10695...

# %%
database.describe()
# Out:
#             pmid       pmcid  \
# count        150         122
# unique       122         100
# top     36990297  PMC8715665
# freq           3           3
#
#                                                     title category  \
# count                                                 149      150
# unique                                                121        6
# top     COVID-19 vaccination for the prevention and tr...   review
# freq                                                    3       65
#
#                                                  pmc_link
# count                                                 122
# unique                                                100
# top     https://pmc.ncbi.nlm.nih.gov/articles/PMC8715665/
# freq                                                    3

# %%
database.duplicated(subset=['pmid']).sum()
# Out:
# np.int64(28)

# %%
database[database.duplicated(subset=['pmid'], keep=False)]
# Out:
#          pmid        pmcid                                              title  \
# 13   40305533         None  Predictors of post-COVID-19 syndrome: a meta-a...
# 14   38834107         None  Early use of oral antiviral drugs and the risk...
# 15   38321404  PMC10848453  The global prevalence of depression, anxiety, ...
# 16   36990297  PMC10067136  COVID-19 vaccination for the prevention and tr...
# 18   35121209   PMC8798975  Mid and long-term neurological and neuropsychi...
# 19   34973396   PMC8715665  Fatigue and cognitive impairment in Post-COVID...
# 22   39905419  PMC11792378  Balneotherapy for the treatment of post-COVID ...
# 23   39665835  PMC11922198  Exercise rehabilitation in post COVID-19 patie...
# 27   38937986  PMC11446691  Telerehabilitation improves cardiorespiratory ...
# 34   38528512  PMC10964649  Effect of home-based pulmonary rehabilitation ...
# 39   38213055         None  Effectiveness of Internet-Based Group Supporti...
# 43   37055254   PMC9981521  Comparison of two antifibrotic treatments for ...
# 44   37301934  PMC10257166  The effect of hyperbaric oxygen therapy on myo...
# 48   36476156   PMC9829459  Effects of a concurrent training, respiratory ...
# 51   36121338   PMC9608026  Influence of Manual Diaphragm Release Techniqu...
# 57   35131031   PMC8896831  Investigating phenotypes of pulmonary COVID-19...
# 61   33831043   PMC8031743  Post-COVID-19 syndrome among symptomatic COVID...
# 63   39905419  PMC11792378  Balneotherapy for the treatment of post-COVID ...
# 64   39665835  PMC11922198  Exercise rehabilitation in post COVID-19 patie...
# 65   38937986  PMC11446691  Telerehabilitation improves cardiorespiratory ...
# 66   38528512  PMC10964649  Effect of home-based pulmonary rehabilitation ...
# 67   38213055         None  Effectiveness of Internet-Based Group Supporti...
# 68   37055254   PMC9981521  Comparison of two antifibrotic treatments for ...
# 69   37301934  PMC10257166  The effect of hyperbaric oxygen therapy on myo...
# 70   36476156   PMC9829459  Effects of a concurrent training, respiratory ...
# 71   36121338   PMC9608026  Influence of Manual Diaphragm Release Techniqu...
# 72   35131031   PMC8896831  Investigating phenotypes of pulmonary COVID-19...
# 73   33831043   PMC8031743  Post-COVID-19 syndrome among symptomatic COVID...
# 74   40305533         None  Predictors of post-COVID-19 syndrome: a meta-a...
# 75   39362575         None  Immune Response and Cognitive Impairment in Po...
# 78   38834107         None  Early use of oral antiviral drugs and the risk...
# 80   38321404  PMC10848453  The global prevalence of depression, anxiety, ...
# 87   36990297  PMC10067136  COVID-19 vaccination for the prevention and tr...
# 94   36708608   PMC9840228  Towards evidence-based and inclusive models of...
# 108  35177424   PMC9258567  Molecular Imaging Findings on Acute and Long-T...
# 114  35121209   PMC8798975  Mid and long-term neurological and neuropsychi...
# 117  34973396   PMC8715665  Fatigue and cognitive impairment in Post-COVID...
# 118  34655247   PMC8661973  Covid-19 sequelae in working age patients: A s...
# 124  34619491   PMC8482840  Onset and frequency of depression in post-COVI...
# 136  34066174   PMC8151698  A Review of Prolonged Post-COVID-19 Symptoms a...
# 139  40305533         None  Predictors of post-COVID-19 syndrome: a meta-a...
# 140  39362575         None  Immune Response and Cognitive Impairment in Po...
# 141  38834107         None  Early use of oral antiviral drugs and the risk...
# 142  38321404  PMC10848453  The global prevalence of depression, anxiety, ...
# 143  36990297  PMC10067136  COVID-19 vaccination for the prevention and tr...
# 144  36708608   PMC9840228  Towards evidence-based and inclusive models of...
# 145  35177424   PMC9258567  Molecular Imaging Findings on Acute and Long-T...
# 146  34973396   PMC8715665  Fatigue and cognitive impairment in Post-COVID...
# 147  34655247   PMC8661973  Covid-19 sequelae in working age patients: A s...
# 148  34619491   PMC8482840  Onset and frequency of depression in post-COVI...
# 149  34066174   PMC8151698  A Review of Prolonged Post-COVID-19 Symptoms a...
#
#                        category  \
# 13   clinical trial phase three
# 14   clinical trial phase three
# 15   clinical trial phase three
# 16   clinical trial phase three
# 18   clinical trial phase three
# 19   clinical trial phase three
# 22               clinical study
# 23               clinical study
# 27               clinical study
# 34               clinical study
# 39               clinical study
# 43               clinical study
# 44               clinical study
# 48               clinical study
# 51               clinical study
# 57               clinical study
# 61               clinical study
# 63               clinical trial
# 64               clinical trial
# 65               clinical trial
# 66               clinical trial
# 67               clinical trial
# 68               clinical trial
# 69               clinical trial
# 70               clinical trial
# 71               clinical trial
# 72               clinical trial
# 73               clinical trial
# 74                       review
# 75                       review
# 78                       review
# 80                       review
# 87                       review
# 94                       review
# 108                      review
# 114                      review
# 117                      review
# 118                      review
# 124                      review
# 136                      review
# 139           systematic review
# 140           systematic review
# 141           systematic review
# 142           systematic review
# 143           systematic review
# 144           systematic review
# 145           systematic review
# 146           systematic review
# 147           systematic review
# 148           systematic review
# 149           systematic review
#
#                                               pmc_link
# 13                                                None
# 14                                                None
# 15   https://pmc.ncbi.nlm.nih.gov/articles/PMC10848...
# 16   https://pmc.ncbi.nlm.nih.gov/articles/PMC10067...
# 18   https://pmc.ncbi.nlm.nih.gov/articles/PMC8798975/
# 19   https://pmc.ncbi.nlm.nih.gov/articles/PMC8715665/
# 22   https://pmc.ncbi.nlm.nih.gov/articles/PMC11792...
# 23   https://pmc.ncbi.nlm.nih.gov/articles/PMC11922...
# 27   https://pmc.ncbi.nlm.nih.gov/articles/PMC11446...
# 34   https://pmc.ncbi.nlm.nih.gov/articles/PMC10964...
# 39                                                None
# 43   https://pmc.ncbi.nlm.nih.gov/articles/PMC9981521/
# 44   https://pmc.ncbi.nlm.nih.gov/articles/PMC10257...
# 48   https://pmc.ncbi.nlm.nih.gov/articles/PMC9829459/
# 51   https://pmc.ncbi.nlm.nih.gov/articles/PMC9608026/
# 57   https://pmc.ncbi.nlm.nih.gov/articles/PMC8896831/
# 61   https://pmc.ncbi.nlm.nih.gov/articles/PMC8031743/
# 63   https://pmc.ncbi.nlm.nih.gov/articles/PMC11792...
# 64   https://pmc.ncbi.nlm.nih.gov/articles/PMC11922...
# 65   https://pmc.ncbi.nlm.nih.gov/articles/PMC11446...
# 66   https://pmc.ncbi.nlm.nih.gov/articles/PMC10964...
# 67                                                None
# 68   https://pmc.ncbi.nlm.nih.gov/articles/PMC9981521/
# 69   https://pmc.ncbi.nlm.nih.gov/articles/PMC10257...
# 70   https://pmc.ncbi.nlm.nih.gov/articles/PMC9829459/
# 71   https://pmc.ncbi.nlm.nih.gov/articles/PMC9608026/
# 72   https://pmc.ncbi.nlm.nih.gov/articles/PMC8896831/
# 73   https://pmc.ncbi.nlm.nih.gov/articles/PMC8031743/
# 74                                                None
# 75                                                None
# 78                                                None
# 80   https://pmc.ncbi.nlm.nih.gov/articles/PMC10848...
# 87   https://pmc.ncbi.nlm.nih.gov/articles/PMC10067...
# 94   https://pmc.ncbi.nlm.nih.gov/articles/PMC9840228/
# 108  https://pmc.ncbi.nlm.nih.gov/articles/PMC9258567/
# 114  https://pmc.ncbi.nlm.nih.gov/articles/PMC8798975/
# 117  https://pmc.ncbi.nlm.nih.gov/articles/PMC8715665/
# 118  https://pmc.ncbi.nlm.nih.gov/articles/PMC8661973/
# 124  https://pmc.ncbi.nlm.nih.gov/articles/PMC8482840/
# 136  https://pmc.ncbi.nlm.nih.gov/articles/PMC8151698/
# 139                                               None
# 140                                               None
# 141                                               None
# 142  https://pmc.ncbi.nlm.nih.gov/articles/PMC10848...
# 143  https://pmc.ncbi.nlm.nih.gov/articles/PMC10067...
# 144  https://pmc.ncbi.nlm.nih.gov/articles/PMC9840228/
# 145  https://pmc.ncbi.nlm.nih.gov/articles/PMC9258567/
# 146  https://pmc.ncbi.nlm.nih.gov/articles/PMC8715665/
# 147  https://pmc.ncbi.nlm.nih.gov/articles/PMC8661973/
# 148  https://pmc.ncbi.nlm.nih.gov/articles/PMC8482840/
# 149  https://pmc.ncbi.nlm.nih.gov/articles/PMC8151698/

# %%
clean_database = database.drop_duplicates(subset='pmid', keep='first')

# %%
clean_database.describe()
# Out:
#             pmid        pmcid  \
# count        122          100
# unique       122          100
# top     39621236  PMC11971158
# freq           1            1
#
#                                                     title category  \
# count                                                 121      122
# unique                                                121        4
# top     Syncopes, paresis and loss of vision after COV...   review
# freq                                                    1       59
#
#                                                  pmc_link
# count                                                 100
# unique                                                100
# top     https://pmc.ncbi.nlm.nih.gov/articles/PMC11971...
# freq                                                    1

# %%
clean_database.category.unique()
# Out:
# array(['case report', 'clinical trial phase three', 'clinical study',
#        'review'], dtype=object)

# %%
clean_database.sample(10)
# Out:
#          pmid        pmcid                                              title  \
# 104  35489015   PMC9055372  Evidence mapping and review of long-COVID and ...
# 129  34024217   PMC8146298  Long COVID or post-COVID-19 syndrome: putative...
# 103  35138001   PMC9111040  Neurological complications associated with Cov...
# 125  34319569   PMC8317481  Long COVID, a comprehensive systematic scoping...
# 24   39423759         None  Analysis of fat oxidation capacity during card...
# 109  35632823   PMC9147674  Dysregulated Immune Responses in SARS-CoV-2-In...
# 130  34384972   PMC8317446  Post COVID-19 Syndrome ("Long COVID") and Diab...
# 1    39988835  PMC11868965  Severe COVID-19 Pneumonia, Opportunistic Candi...
# 81   38139400  PMC10743535  Resveratrol and Gut Microbiota Synergy: Preven...
# 7    36822507   PMC9943558  Leveraging Serologic Testing to Identify Child...
#
#            category                                           pmc_link
# 104          review  https://pmc.ncbi.nlm.nih.gov/articles/PMC9055372/
# 129          review  https://pmc.ncbi.nlm.nih.gov/articles/PMC8146298/
# 103          review  https://pmc.ncbi.nlm.nih.gov/articles/PMC9111040/
# 125          review  https://pmc.ncbi.nlm.nih.gov/articles/PMC8317481/
# 24   clinical study                                               None
# 109          review  https://pmc.ncbi.nlm.nih.gov/articles/PMC9147674/
# 130          review  https://pmc.ncbi.nlm.nih.gov/articles/PMC8317446/
# 1       case report  https://pmc.ncbi.nlm.nih.gov/articles/PMC11868...
# 81           review  https://pmc.ncbi.nlm.nih.gov/articles/PMC10743...
# 7       case report  https://pmc.ncbi.nlm.nih.gov/articles/PMC9943558/

# %% [markdown]
# #### Scraping the PDF Download Links
#
# This section focuses on extracting direct PDF download links for the articles identified in the previous steps. It accomplishes this by:
#
# 1.  **Setting up Selenium:** Configures Selenium with Chrome options for headless browsing, necessary for interacting with dynamic web content and potentially bypassing bot detection.
# 2.  **Defining `resolve_pdf_url` function:** This function takes a PMC article link, appends "/pdf/" to it, and attempts to resolve the final redirected URL. This is crucial because the direct "/pdf/" link on PMC often redirects to the actual PDF file location. It handles potential `requests.RequestException` errors and uses `allow_redirects=True` and `stream=True` for efficient handling of the response without downloading the entire PDF. A user agent is included to be polite during requests.
# 3.  **Defining `get_download_links` function (Implicitly in the ThreadPoolExecutor):** The code then utilizes a `concurrent.futures.ThreadPoolExecutor` to efficiently process the PMC links in parallel. For each valid PMC link in the `clean_database`, the `resolve_pdf_url` function is called within a thread to retrieve the corresponding PDF download link.
# 4.  **Executing the scraping:** The `ThreadPoolExecutor` manages the concurrent execution of the `resolve_pdf_url` function for all PMC links, and `tqdm` is used to display a progress bar during this process.
# 5.  **Adding download links to DataFrame:** The extracted PDF download links (or `None` if resolution failed) are collected in a list and then added as a new column (`download_links`) to a copy of the `clean_database` DataFrame.
# 6.  **Handling missing PMIDs:** Rows with missing PMIDs are explicitly dropped from the updated DataFrame (`clean_database_with_pdfs`).
#
# The resulting DataFrame (`clean_database_with_pdfs`) now includes a column with direct links to the PDF versions of the articles, where available, obtained through a process that attempts to resolve the actual PDF location via redirection.

# %%
headers = {
    "content-type": "text/html; charset=utf-8",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36",
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8",
    "accept-encoding": "gzip, deflate, br",
    "accept-language": "en-US,en;q=0.9",
    "cache-control": "no-cache",
    "pragma": "no-cache",
}

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import WebDriverException
import time

# %%
def make_driver():
    options = Options()
    options.add_argument("--headless=new")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    options.page_load_strategy = "eager"  # Faster than default "normal"
    return webdriver.Chrome(options=options)

# %%
def get_final_pdf_url(pmc_url: str) -> str | None:
    try:
        driver = make_driver()
        driver.set_page_load_timeout(15)  # Prevent infinite hangs

        pdf_url = pmc_url.rstrip("/") + "/pdf/"
        driver.get(pdf_url)

        final_url = driver.current_url
        return final_url
    except WebDriverException as e:
        print(f"Error on {pmc_url}: {e}")
        return None
    finally:
        try:
            driver.quit()  # Always clean up!
        except Exception:
            pass

# %%
pdfs = []
for link in clean_database.pmc_link.tolist():
  if link!=None:
    print(f"Processing: {link}")
    resolved = get_final_pdf_url(link)
    print(f"Resolved: {resolved}")
    pdfs.append(resolved)
    time.sleep(2)  # Be polite to the server
  else:
    pdfs.append(math.nan)
# Out:
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC11971158/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC11971158/pdf/15010_2024_Article_2439.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC11868965/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC11868965/pdf/amjcaserep-26-e946400.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC11296404/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC11296404/pdf/medi-103-e39121.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC10469423/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC10469423/pdf/TEMI_12_2251600.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9826535/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9826535/pdf/13730_2023_Article_772.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9767890/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9767890/pdf/main.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC10102822/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC10102822/pdf/10.1177_10870547231168338.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9943558/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9943558/pdf/main.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC11132361/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC11132361/pdf/medi-101-e29358.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8996041/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8996041/pdf/bcr-2021-248448.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8855328/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8855328/pdf/amjcaserep-23-e935414.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8561376/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8561376/pdf/13256_2021_Article_3148.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8050227/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8050227/pdf/10286_2021_Article_803.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC10848453/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC10848453/pdf/12888_2023_Article_5481.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC10067136/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC10067136/pdf/main.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8934180/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8934180/pdf/main.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8798975/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8798975/pdf/main.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8715665/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8715665/pdf/main.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC11895281/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC11895281/pdf/12913_2025_Article_12521.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC11855376/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC11855376/pdf/ijerph-22-00261.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC11792378/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC11792378/pdf/12906_2025_Article_4784.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC11922198/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC11922198/pdf/15-8487-EJPRM_N.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC11546864/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC11546864/pdf/ijms-25-11791.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC11520684/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC11520684/pdf/13063_2024_Article_8571.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC11446691/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC11446691/pdf/JCSM-15-1785.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC11528924/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC11528924/pdf/10.1177_02692155241262871.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC11404027/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC11404027/pdf/40359_2024_Article_1974.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC11130769/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC11130769/pdf/
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC11055275/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC11055275/pdf/12904_2024_Article_1437.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC10964649/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC10964649/pdf/12984_2024_Article_1340.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC10904373/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC10904373/pdf/41598_2024_Article_54554.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC10771676/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC10771676/pdf/12879_2023_Article_8925.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC10695477/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC10695477/pdf/1678-4464-csp-39-11-PT243722.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC10542303/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC10542303/pdf/10456_2023_Article_9885.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC10488264/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC10488264/pdf/ijerph-20-06697.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9981521/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9981521/pdf/main.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC10257166/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC10257166/pdf/41598_2023_Article_36570.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC10248954/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC10248954/pdf/42358_2023_Article_309.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC10335413/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC10335413/pdf/bmjopen-2022-069217.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC10062549/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC10062549/pdf/pone.0283758.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9829459/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9829459/pdf/
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9680157/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9680157/pdf/bmjopen-2022-066044.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9654654/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9654654/pdf/ijerph-19-14224.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9608026/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9608026/pdf/JRM-54-3972.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9568911/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9568911/pdf/13063_2022_Article_6817.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9426365/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9426365/pdf/41467_2022_Article_32507.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9394845/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9394845/pdf/pone.0273041.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8920113/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8920113/pdf/main.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8662016/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8662016/pdf/JMV-94-1027.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8896831/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8896831/pdf/elife-72500.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8637041/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8637041/pdf/13063_2021_Article_5569.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8457337/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8457337/pdf/
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8031743/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8031743/pdf/pone.0249644.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8727683/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8727683/pdf/bmjopen-2020-048391.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC11818037/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC11818037/pdf/12916_2025_Article_3927.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC11436955/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC11436955/pdf/ldae008.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC10886368/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC10886368/pdf/arm-92-00013.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC10743535/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC10743535/pdf/ijms-24-17573.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC10673195/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC10673195/pdf/medicina-59-01961.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC10287165/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC10287165/pdf/fimmu-14-1161067.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC10136381/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC10136381/pdf/59_2023_Article_5170.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9512521/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9512521/pdf/main.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC10221134/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC10221134/pdf/medicina-59-00818.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC10094973/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC10094973/pdf/ijms-24-06583.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9840228/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9840228/pdf/main.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9964207/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9964207/pdf/viruses-15-00533.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC10015558/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC10015558/pdf/JMedLife-16-195.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9828583/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9828583/pdf/jcprh-43-8.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9784943/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9784943/pdf/viruses-14-02797.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9637536/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9637536/pdf/main.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9781151/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9781151/pdf/viruses-14-02600.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9111040/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9111040/pdf/RMV-9999-0.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9055372/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9055372/pdf/15010_2022_Article_1835.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9187867/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9187867/pdf/main.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9413998/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9413998/pdf/viruses-14-01686.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9258567/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9258567/pdf/jnm263085.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9147674/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9147674/pdf/viruses-14-01082.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9111001/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9111001/pdf/PTR-36-2042.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8848724/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8848724/pdf/main.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9028501/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9028501/pdf/ijms-23-04275.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8954128/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8954128/pdf/nutrients-14-01305.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8924116/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8924116/pdf/fimmu-13-838011.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8661973/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8661973/pdf/JMV-94-858.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8835786/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8835786/pdf/ijms-23-01716.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC9127978/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC9127978/pdf/nihms-1804958.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8629735/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8629735/pdf/10067_2021_Article_6001.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8209771/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8209771/pdf/41380_2021_Article_1148.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8482840/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8482840/pdf/main.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8317481/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8317481/pdf/15010_2021_Article_1666.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8607226/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8607226/pdf/12967_2021_Article_3143.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8646640/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8646640/pdf/SJI-94-e13101.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8420624/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8420624/pdf/pzab155.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8146298/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8146298/pdf/INFD_0_1924397.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8317446/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8317446/pdf/main.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8450986/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8450986/pdf/10.1177_01410768211032850.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8180841/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8180841/pdf/main.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8156194/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8156194/pdf/ijerph-18-05329.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8151698/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8151698/pdf/ijerph-18-05131.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC8090526/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC8090526/pdf/40035_2021_Article_237.pdf
# Processing: https://pmc.ncbi.nlm.nih.gov/articles/PMC7924007/
# Resolved: https://pmc.ncbi.nlm.nih.gov/articles/PMC7924007/pdf/medscimonit-27-e931447.pdf

# %%
len(clean_database.pmc_link.tolist())
# Out:
# 122

# %%
clean_database = clean_database.reset_index(drop=True)

# %%
df_pdfs = pd.DataFrame({"download_link":pdfs})
df_pdfs
# Out:
#                                          download_link
# 0    https://pmc.ncbi.nlm.nih.gov/articles/PMC11971...
# 1    https://pmc.ncbi.nlm.nih.gov/articles/PMC11868...
# 2    https://pmc.ncbi.nlm.nih.gov/articles/PMC11296...
# 3    https://pmc.ncbi.nlm.nih.gov/articles/PMC10469...
# 4    https://pmc.ncbi.nlm.nih.gov/articles/PMC98265...
# ..                                                 ...
# 117                                                NaN
# 118  https://pmc.ncbi.nlm.nih.gov/articles/PMC81561...
# 119  https://pmc.ncbi.nlm.nih.gov/articles/PMC81516...
# 120  https://pmc.ncbi.nlm.nih.gov/articles/PMC80905...
# 121  https://pmc.ncbi.nlm.nih.gov/articles/PMC79240...
#
# [122 rows x 1 columns]

# %%
database_pdfs = pd.concat([clean_database, pd.DataFrame({"download_link":pdfs})],
                          axis=1).reset_index(drop=True)
database_pdfs
# Out:
#          pmid        pmcid                                              title  \
# 0    39621236  PMC11971158  Syncopes, paresis and loss of vision after COV...
# 1    39988835  PMC11868965  Severe COVID-19 Pneumonia, Opportunistic Candi...
# 2    39093769  PMC11296404  Integrative personalized medicine care for adj...
# 3    37606967  PMC10469423  Severe pigeon paramyxovirus 1 infection in a h...
# 4    36617353   PMC9826535  Post-COVID-19 syndrome increased the requireme...
# ..        ...          ...                                                ...
# 117  34042167         None  Post-COVID-19 syndrome: epidemiology, diagnost...
# 118  34067776   PMC8156194  Post-COVID-19 Syndrome and the Potential Benef...
# 119  34066174   PMC8151698  A Review of Prolonged Post-COVID-19 Symptoms a...
# 120  33941272   PMC8090526  COVID-19 and Alzheimer's disease: how one cris...
# 121  33633106   PMC7924007  Historical Insight into Infections and Disorde...
#
#         category                                           pmc_link  \
# 0    case report  https://pmc.ncbi.nlm.nih.gov/articles/PMC11971...
# 1    case report  https://pmc.ncbi.nlm.nih.gov/articles/PMC11868...
# 2    case report  https://pmc.ncbi.nlm.nih.gov/articles/PMC11296...
# 3    case report  https://pmc.ncbi.nlm.nih.gov/articles/PMC10469...
# 4    case report  https://pmc.ncbi.nlm.nih.gov/articles/PMC9826535/
# ..           ...                                                ...
# 117       review                                               None
# 118       review  https://pmc.ncbi.nlm.nih.gov/articles/PMC8156194/
# 119       review  https://pmc.ncbi.nlm.nih.gov/articles/PMC8151698/
# 120       review  https://pmc.ncbi.nlm.nih.gov/articles/PMC8090526/
# 121       review  https://pmc.ncbi.nlm.nih.gov/articles/PMC7924007/
#
#                                          download_link
# 0    https://pmc.ncbi.nlm.nih.gov/articles/PMC11971...
# 1    https://pmc.ncbi.nlm.nih.gov/articles/PMC11868...
# 2    https://pmc.ncbi.nlm.nih.gov/articles/PMC11296...
# 3    https://pmc.ncbi.nlm.nih.gov/articles/PMC10469...
# 4    https://pmc.ncbi.nlm.nih.gov/articles/PMC98265...
# ..                                                 ...
# 117                                                NaN
# 118  https://pmc.ncbi.nlm.nih.gov/articles/PMC81561...
# 119  https://pmc.ncbi.nlm.nih.gov/articles/PMC81516...
# 120  https://pmc.ncbi.nlm.nih.gov/articles/PMC80905...
# 121  https://pmc.ncbi.nlm.nih.gov/articles/PMC79240...
#
# [122 rows x 6 columns]

# %% [markdown]
# #### DataFrame Cleaning

# %%
clean_database.isna().sum()
# Out:
# pmid         0
# pmcid       22
# title        1
# category     0
# pmc_link    22
# dtype: int64

# %%
manual_pdfs = database_pdfs[database_pdfs.isnull().any(axis=1)]
manual_pdfs
# Out:
#          pmid pmcid                                              title  \
# 13   40305533  None  Predictors of post-COVID-19 syndrome: a meta-a...
# 14   38834107  None  Early use of oral antiviral drugs and the risk...
# 24   39423759  None  Analysis of fat oxidation capacity during card...
# 30   38436080  None  Low-intensity rehabilitation in persistent pos...
# 33   37201931  None  Vision impairment is common in non-hospitalise...
# 39   38213055  None  Effectiveness of Internet-Based Group Supporti...
# 40   37690207  None  Factors associated with mental health outcomes...
# 42   37184376  None  Long-term consequences in Covid-19 and Non-Cov...
# 59   34719599  None  Post COVID-19 sequelae: A prospective observat...
# 63   39362575  None  Immune Response and Cognitive Impairment in Po...
# 69   37834270  None                                               None
# 70   37595427  None  Post-COVID-19 syndrome management: Utilizing t...
# 71   37423295  None  Chronic inflammation, neuroglial dysfunction, ...
# 72   37021969  None  Psychiatric manifestations of post-COVID-19 sy...
# 77   37070922  None                          COVID-19 and bone health.
# 83   36534494  None  Assessment of life quality and health percepti...
# 87   35428040  None                An overview of post COVID sequelae.
# 91   36066294  None  Multisystem involvement in COVID-19: what have...
# 100  35363367  None  The endocrine system function disturbances dur...
# 105  36657113  None  What is post-COVID-19 syndrome? Definition and...
# 116  34486708  None  Staying tuned for post-COVID-19 syndrome: look...
# 117  34042167  None  Post-COVID-19 syndrome: epidemiology, diagnost...
#
#                        category pmc_link download_link
# 13   clinical trial phase three     None           NaN
# 14   clinical trial phase three     None           NaN
# 24               clinical study     None           NaN
# 30               clinical study     None           NaN
# 33               clinical study     None           NaN
# 39               clinical study     None           NaN
# 40               clinical study     None           NaN
# 42               clinical study     None           NaN
# 59               clinical study     None           NaN
# 63                       review     None           NaN
# 69                       review     None           NaN
# 70                       review     None           NaN
# 71                       review     None           NaN
# 72                       review     None           NaN
# 77                       review     None           NaN
# 83                       review     None           NaN
# 87                       review     None           NaN
# 91                       review     None           NaN
# 100                      review     None           NaN
# 105                      review     None           NaN
# 116                      review     None           NaN
# 117                      review     None           NaN

# %% [markdown]
# ##### Changing Error Title Value

# %%
# PMID 37106076
database_pdfs.loc[database_pdfs.pmid == '37106076'].title.values[0]
# Out:
# 'Multisystem involvement in COVID-19: what have we learnt?'

# %%
database_pdfs.replace(to_replace=database_pdfs.loc[database_pdfs.pmid == '37106076'].title.values[0],
                      value= "Post-COVID-More than chronic fatigue?", inplace=True)

# %%
database_pdfs.loc[database_pdfs.pmid == '37106076'].title.values[0]
# Out:
# 'Post-COVID-More than chronic fatigue?'

# %%
# PMID 36066294
database_pdfs.loc[database_pdfs.pmid == '36066294'].title.values[0]
# Out:
# "Multisystem involvement in COVID-19: what have we learnt? PG - 1-5 LID - 10.12968/hmed.2022.0290 [doi] AB - The COVID-19 illness trajectory involves persistent cardio-renal inflammation, activation of the haemostatic pathway and lung involvement. Results of a study carried out by the authors' team demonstrate a link between post-COVID-19 syndrome (people who have long COVID) and multisystem disease, which partly explains the lingering impairments in patient-reported health-related quality of life, physical function and psychological wellbeing after COVID-19. This article discusses what hospital physicians need to be aware of when considering the likelihood of myocarditis in patients with post-COVID-19 syndrome and the implications in the longer term."

# %%
database_pdfs.replace(to_replace=database_pdfs.loc[database_pdfs.pmid == '36066294'].title.values[0],
                      value= "Multisystem involvement in COVID-19: what have we learnt?", inplace=True)

# %%
database_pdfs.loc[database_pdfs.pmid == '37106076'].title.values[0]
# Out:
# 'Post-COVID-More than chronic fatigue?'

# %%
# PMID 34140635
database_pdfs.loc[database_pdfs.pmid == '34140635'].title.values[0]
# Out:
# 'Chronic post-COVID-19 syndrome and chronic fatigue syndrome: Is there a role for extracorporeal apheresis? PG - 34-37 LID - 10.1038/s41380-021-01148-4 [doi] AB - As millions of patients have been infected by SARS-CoV-2 virus a vast number of individuals complain about continuing breathlessness and fatigue even months after the onset of the disease. This overwhelming phenomenon has not been well defined and has been called "post-COVID syndrome" or "long-COVID" [1]. There are striking similarities to myalgic encephalomyelitis also called chronic fatigue syndrome linked to a viral and autoimmune pathogenesis. In both disorders neurotransmitter receptor antibodies against ß-adrenergic and muscarinic receptors may play a key role. We found similar elevation of these autoantibodies in both patient groups. Extracorporeal apheresis using a special filter seems to be effective in reducing these antibodies in a significant way clearly improving the debilitating symptoms of patients with chronic fatigue syndrome. Therefore, such a form of neuropheresis may provide a promising therapeutic option for patients with post-COVID-19 syndrome. This method will also be effective when other hitherto unknown antibodies and inflammatory mediators are involved.'

# %%
database_pdfs.replace(to_replace=database_pdfs.loc[database_pdfs.pmid == '34140635'].title.values[0],
                      value= "Chronic post-COVID-19 syndrome and chronic fatigue syndrome: Is there a role for extracorporeal apheresis?", inplace=True)

# %%
database_pdfs.loc[database_pdfs.pmid == '34140635'].title.values[0]
# Out:
# 'Chronic post-COVID-19 syndrome and chronic fatigue syndrome: Is there a role for extracorporeal apheresis?'

# %%
database_final = database_pdfs[database_pdfs.isnull().any(axis=1) == False].reset_index(drop=True)
database_final
# Out:
#         pmid        pmcid                                              title  \
# 0   39621236  PMC11971158  Syncopes, paresis and loss of vision after COV...
# 1   39988835  PMC11868965  Severe COVID-19 Pneumonia, Opportunistic Candi...
# 2   39093769  PMC11296404  Integrative personalized medicine care for adj...
# 3   37606967  PMC10469423  Severe pigeon paramyxovirus 1 infection in a h...
# 4   36617353   PMC9826535  Post-COVID-19 syndrome increased the requireme...
# ..       ...          ...                                                ...
# 95  34175230   PMC8180841  Insights from myalgic encephalomyelitis/chroni...
# 96  34067776   PMC8156194  Post-COVID-19 Syndrome and the Potential Benef...
# 97  34066174   PMC8151698  A Review of Prolonged Post-COVID-19 Symptoms a...
# 98  33941272   PMC8090526  COVID-19 and Alzheimer's disease: how one cris...
# 99  33633106   PMC7924007  Historical Insight into Infections and Disorde...
#
#        category                                           pmc_link  \
# 0   case report  https://pmc.ncbi.nlm.nih.gov/articles/PMC11971...
# 1   case report  https://pmc.ncbi.nlm.nih.gov/articles/PMC11868...
# 2   case report  https://pmc.ncbi.nlm.nih.gov/articles/PMC11296...
# 3   case report  https://pmc.ncbi.nlm.nih.gov/articles/PMC10469...
# 4   case report  https://pmc.ncbi.nlm.nih.gov/articles/PMC9826535/
# ..          ...                                                ...
# 95       review  https://pmc.ncbi.nlm.nih.gov/articles/PMC8180841/
# 96       review  https://pmc.ncbi.nlm.nih.gov/articles/PMC8156194/
# 97       review  https://pmc.ncbi.nlm.nih.gov/articles/PMC8151698/
# 98       review  https://pmc.ncbi.nlm.nih.gov/articles/PMC8090526/
# 99       review  https://pmc.ncbi.nlm.nih.gov/articles/PMC7924007/
#
#                                         download_link
# 0   https://pmc.ncbi.nlm.nih.gov/articles/PMC11971...
# 1   https://pmc.ncbi.nlm.nih.gov/articles/PMC11868...
# 2   https://pmc.ncbi.nlm.nih.gov/articles/PMC11296...
# 3   https://pmc.ncbi.nlm.nih.gov/articles/PMC10469...
# 4   https://pmc.ncbi.nlm.nih.gov/articles/PMC98265...
# ..                                                ...
# 95  https://pmc.ncbi.nlm.nih.gov/articles/PMC81808...
# 96  https://pmc.ncbi.nlm.nih.gov/articles/PMC81561...
# 97  https://pmc.ncbi.nlm.nih.gov/articles/PMC81516...
# 98  https://pmc.ncbi.nlm.nih.gov/articles/PMC80905...
# 99  https://pmc.ncbi.nlm.nih.gov/articles/PMC79240...
#
# [100 rows x 6 columns]

# %%
database_final.describe()
# Out:
#             pmid        pmcid  \
# count        100          100
# unique       100          100
# top     39621236  PMC11971158
# freq           1            1
#
#                                                     title category  \
# count                                                 100      100
# unique                                                100        4
# top     Syncopes, paresis and loss of vision after COV...   review
# freq                                                    1       46
#
#                                                  pmc_link  \
# count                                                 100
# unique                                                100
# top     https://pmc.ncbi.nlm.nih.gov/articles/PMC11971...
# freq                                                    1
#
#                                             download_link
# count                                                 100
# unique                                                100
# top     https://pmc.ncbi.nlm.nih.gov/articles/PMC11971...
# freq                                                    1

# %% [markdown]
# ##### exporting to csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
database_final.to_csv("pasc_pubmed.csv",index=False)
